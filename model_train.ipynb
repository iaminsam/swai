# %% [markdown]
# <STEP 1> Google 드라이브 연결, 이미지 파일 압축 풀기

# %%
epochN = None; learnRate = None                                                 # epochN = 2~10, learnRate = 0.0005/0.0010/0.0015/0.0020/0.0025
import glob, zipfile
from google.colab import drive
drive.mount('/content/drive')                                                   # Google Drive 연결
imageDir = 'donaldCar'; outDir = '/content/drive/MyDrive/'+imageDir             # Google Drive 에서 도로 이미지가 저장된 디렉터리 이름, 학습 파일, plot이미지 저장 위치
fileList = glob.glob(outDir+'/*.zip'); print(f'자율주행 프로젝트는 {len(fileList)} 개 입니다.')  # 검사 조건에 만족하는 파일 리스트 생성, 프로젝트 개수 프린트
for t in fileList:                                                              # 프로젝트 이름 프린트
    u = t.split('/'); v = u[-1]; w = v.split('.'); p = w[-2]; print(p)          # 파일 이름 추출 '/' 문자를 기준으로 분리하여 리스트 생성
project = input('자율주행 프로젝트 이름을 입력하세요:')                          # 자율 주행 프로젝트 이름 입력하고 엔터키 입력
if project == '': project = p                                                   # 이름 없이 [Enter] 키만 입력하면 마지막 파일을 사용
local_zip =  '/content/drive/MyDrive/'+imageDir+'/'+project+'.zip'; print(local_zip) # 코랩 donaldCar 폴더안의 다운받은 Zip 파일 경로(path)
zip_ref = zipfile.ZipFile(local_zip, 'r'); zip_ref.extractall(); zip_ref.close()     # 디폴트 폴더에 압축 풀기
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# 자율주행 프로젝트는 55 개 입니다.
# wtrk1
# ftrk2
# wtrk2
# track
# demot
# demoY
# demou
# wtrk4
# wnway
# wnway3
# wnway4
# wnway5
# wnway6
# wnway7
# wnway9
# wnwayA
# ysd1
# ngit1
# roada
# roadb
# rway3
# trkb
# trkc
# trkd
# trke
# grst1
# grst0
# grst2
# grst2A
# abc
# abcd
# winf
# aaa
# aab
# aac
# aad
# aae
# a8h
# ts2
# workA
# num_5
# workB
# workT
# workC
# workD
# workE
# work4B
# workH
# workG
# workL
# workM
# testB
# testC
# hy01
# workP
# 자율주행 프로젝트 이름을 입력하세요:
# /content/drive/MyDrive/donaldCar/workP.zip

# %% [markdown]
# <STEP 2> 라이브러리 가져오기(Import)

# %%
import os
import sys
import random
import fnmatch
import pickle
import time
import numpy as np
import cv2 as cv                                 # Open Cv 영상처리 라이브러리
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, Dataset
import torch.nn.functional as F
import torch.optim as optim
from sklearn.metrics import mean_squared_error, r2_score
# %matplotlib inline
from PIL import Image

print(f'Python Version:     {sys.version}')                                     # Python Version 
print(f'OpenCV version:     {cv.__version__}')                                  # Open CV version
print(f'Pytorch version:    {torch.__version__}')                               # Pytorch version
# Out:
# Python Version:     3.8.16 (default, Dec  7 2022, 01:12:13)
# [GCC 7.5.0]
# OpenCV version:     4.6.0
# Pytorch version:    1.13.0+cu116

# %% [markdown]
# <STEP 3> 이미지 데이터 조향각 추출

# %%
dataDir = '/content/'+project                                                   # colab 내부 프로젝트 디렉터리
with open(f'{dataDir}/{project}.pickle', 'rb') as f:                            # pickle 
    x_exam_Image = pickle.load(f)                                               # 시험 이미지 파일 이름 리스트
    x_valid_Image = pickle.load(f)                                              # 평가 이미지 파일 이름 리스트
    x_train_Image = pickle.load(f)                                              # 훈련 이미지 파일 이름 리스트
    p = pickle.load(f)                                                          # 파라메터 리스트
if epochN == None:    epochN =    p[0]                                          # 학습회수 2 ~ 10
if learnRate == None: learnRate = p[1]                                          # 학습 비율 0.0005/0.0010/0.0015/0.0020/0.0025
#-------------------------------------------------------------------------------
y_exam_Angle=[]
y_valid_Angle=[]
y_train_Angle = []
for f in x_exam_Image:                   # 시험용 이미지 파일 이름에서 각도값
    y_exam_Angle.append(int(f[-7:-4]))
for f in x_valid_Image:                  # 평가용 이미지 파일 이름에서 각도값
    y_valid_Angle.append(int(f[-7:-4]))
for f in x_train_Image:                  # 훈련용 이미지 파일 이름에서 각도값
    y_train_Angle.append(int(f[-7:-4]))

# %% [markdown]
# <STEP 4> Nvidia CNN 모델 구성, 딥러닝

# %%
# Pytorch device 설정
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
print(f'{device} is available')

# Nvidia CNN 모델 구성 ---------------------------------------------------------
class NvidiaModel(nn.Module):
    def __init__(self):
      super(NvidiaModel, self).__init__()

      # elu=Expenential Linear Unit, similar to leaky Relu
      # skipping 1st hiddel layer (nomralization layer), as we have normalized the data

      # Convolution Layers
      self.layer1 = nn.Sequential(
        nn.Conv2d(in_channels=3, out_channels=24, kernel_size=(5, 5), stride=(2, 2)),
        nn.ELU(inplace=True),
        nn.Conv2d(in_channels=24, out_channels=36, kernel_size=(5, 5), stride=(2, 2)),
        nn.ELU(inplace=True),
        nn.Conv2d(in_channels=36, out_channels=48, kernel_size=(5, 5), stride=(2, 2)),
        nn.ELU(inplace=True),
        nn.Conv2d(in_channels=48, out_channels=64, kernel_size=(3, 3)),
        nn.ELU(inplace=True),
        nn.Dropout(0.2),
        nn.Conv2d(in_channels=64, out_channels=64, kernel_size=(3, 3)),
        nn.ELU(inplace=True)
      )
      
      # Fully Connected Layers
      self.layer2 = nn.Sequential(
        # nn.Flatten(),
        nn.Dropout(0.2),
        nn.Linear(in_features=18 * 64, out_features=100),
        nn.ELU(inplace=True),
        nn.Linear(in_features=100, out_features=50),
        nn.ELU(inplace=True),
        nn.Linear(in_features=50, out_features=10),
        nn.ELU(inplace=True)
      )
      
      # Output Layer
      self.layer3 = nn.Sequential(
        nn.Linear(in_features=10, out_features=1)
      )

    def forward(self, x):
      x = self.layer1(x)
      x = x.view(x.shape[0], -1)
      x = self.layer2(x)
      x = self.layer3(x)

      return x


#-------------------------------------------------------------------------------
def imgPaths(fGroup):
    r = []
    for filename in fGroup:
        r.append(os.path.join(dataDir, filename))                               # 파일 경로(path)를 화일 이름 앞에 부착하여 리스트에 추가
    return(r)

# 학습 데이터 생성 -------------------------------------------------------------
class CustomDataset(Dataset):
    def __init__(self, imageList, angleList):
        self.imageList = imgPaths(imageList)
        self.angleList = angleList

        for i in range(len(imageList)):
            # print(i, self.imageList[i])
            image = cv.imread(self.imageList[i])
            image = image / 255

            self.imageList[i] = image

    def __len__(self):
        return len(self.imageList)

    def __getitem__(self, index):
        images = torch.FloatTensor(self.imageList[index]).permute(2,0,1)
        angles = torch.FloatTensor([self.angleList[index]])

        return images, angles


#-------------------------------------------------------------------------------
class EarlyStopping:
    """주어진 patience 이후로 validation loss가 개선되지 않으면 학습을 조기 중지"""
    def __init__(self, patience=7, verbose=False, delta=0, path=f'{outDir}/{project}_model_check.pt'):
        """
        Args:
            patience (int): validation loss가 개선된 후 기다리는 기간
                            Default: 7
            verbose (bool): True일 경우 각 validation loss의 개선 사항 메세지 출력
                            Default: False
            delta (float): 개선되었다고 인정되는 monitered quantity의 최소 변화
                            Default: 0
            path (str): checkpoint저장 경로
                            Default: 'checkpoint.pt'
        """
        self.patience = patience
        self.verbose = verbose
        self.counter = 0
        self.best_score = None
        self.early_stop = False
        self.val_loss_min = np.Inf
        self.delta = delta
        self.path = path

    def __call__(self, val_loss, model):

        score = -val_loss

        if self.best_score is None:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
        elif score < self.best_score + self.delta:
            self.counter += 1
            print(f'EarlyStopping counter: {self.counter} out of {self.patience}')
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
            self.counter = 0

    def save_checkpoint(self, val_loss, model):
        '''validation loss가 감소하면 모델을 저장한다.'''
        if self.verbose:
            print(f'Validation loss decreased ({self.val_loss_min:.6f} --> {val_loss:.6f}).  Saving model ...')
        torch.save(model.state_dict(), self.path)
        # torch.save(model, self.path)
        self.val_loss_min = val_loss

# 모델 학습 --------------------------------------------------------------------
def learnProc():
  model = NvidiaModel().to(device)

  train_dataset = CustomDataset(x_train_Image, y_train_Angle)
  train_loader = DataLoader(train_dataset, batch_size=len(x_train_Image))

  valid_dataset = CustomDataset(x_valid_Image, y_valid_Angle)
  valid_loader = DataLoader(valid_dataset, batch_size=len(x_valid_Image))

  optimizer = optim.Adam(model.parameters(), lr=learnRate)
  criterion = nn.MSELoss().to(device)

  early_stopping = EarlyStopping(patience=30, verbose=True)

  # EPOCHS = epochN
  EPOCHS = 300
  train_losses = []
  valid_losses = []
  avg_train_losses = []
  avg_valid_losses = []
  for epoch in range(1, EPOCHS + 1):
      # 학습
      model.train()

      for batch_idx, (data, target) in enumerate(train_loader):
          data, target = data.to(device), target.to(device)
          optimizer.zero_grad()

          output = model(data)

          loss = criterion(output.to(torch.float32), target.to(torch.float32))
          loss.backward()
          optimizer.step()

          train_losses.append(loss.item())

      # 검증
      model.eval()

      with torch.no_grad():
        for data, target in valid_loader:
            data, target = data.to(device), target.to(device)

            output = model(data)

            loss = criterion(output.to(torch.float32), target.to(torch.float32))

            valid_losses.append(loss.item())

      train_loss = np.average(train_losses)
      valid_loss = np.average(valid_losses)
      avg_train_losses.append(train_loss)
      avg_valid_losses.append(valid_loss)

      epoch_len = len(str(EPOCHS))

      print_msg = (f'[{epoch:>{epoch_len}}/{EPOCHS:>{epoch_len}}] ' +
                      f'train_loss: {train_loss:.5f} ' +
                      f'valid_loss: {valid_loss:.5f}')

      print(print_msg)

      train_losses = []
      valid_losses = []

      early_stopping(valid_loss, model)

      if early_stopping.early_stop:
          print("Early stopping")
          break

  return {'loss':avg_train_losses, 'val_loss':avg_valid_losses}

# 학습 시작---------------------------------------------------------------------
print()
print('시험 이미지 개수:',len(x_exam_Image))
print('평가 이미지 개수:',len(x_valid_Image))
print('훈련 이미지 개수:',len(x_train_Image)) 
print('학습 비율=', learnRate)
print('학습 회수=', epochN)
print()
startTime = time.time()                                                         # 학습 시작 시간 저장
history = learnProc()                                                           # 학습 시작
elapsedTime = int(time.time() - startTime)                                      # 학습 경과 시간 저장
#-------------------------------------------------------------------------------
plt.plot(history['loss'],color='blue')
plt.plot(history['val_loss'],color='red')
plt.legend(['training loss', 'validation loss'])
plt.savefig(f'{outDir}/{project}_result.png')                                   # plot 이미지 저장
# Out:
# cpu is available
#
# 시험 이미지 개수: 5
# 평가 이미지 개수: 28
# 훈련 이미지 개수: 126
# 학습 비율= 0.001
# 학습 회수= 3
#
# [  1/300] train_loss: 731.83881 valid_loss: 751.05463
# Validation loss decreased (inf --> 751.054626).  Saving model ...
# [  2/300] train_loss: 731.71240 valid_loss: 751.01904
# Validation loss decreased (751.054626 --> 751.019043).  Saving model ...
# [  3/300] train_loss: 731.45874 valid_loss: 750.65265
# Validation loss decreased (751.019043 --> 750.652649).  Saving model ...
# [  4/300] train_loss: 730.70526 valid_loss: 748.64594
# Validation loss decreased (750.652649 --> 748.645935).  Saving model ...
# [  5/300] train_loss: 728.20032 valid_loss: 742.66705
# Validation loss decreased (748.645935 --> 742.667053).  Saving model ...
# [  6/300] train_loss: 721.85040 valid_loss: 732.27979
# Validation loss decreased (742.667053 --> 732.279785).  Saving model ...
# [  7/300] train_loss: 709.31079 valid_loss: 717.00287
# Validation loss decreased (732.279785 --> 717.002869).  Saving model ...
# [  8/300] train_loss: 690.98175 valid_loss: 696.11279
# Validation loss decreased (717.002869 --> 696.112793).  Saving model ...
# [  9/300] train_loss: 667.73102 valid_loss: 671.35590
# Validation loss decreased (696.112793 --> 671.355896).  Saving model ...
# [ 10/300] train_loss: 638.35095 valid_loss: 634.84814
# Validation loss decreased (671.355896 --> 634.848145).  Saving model ...
# [ 11/300] train_loss: 599.42981 valid_loss: 581.57434
# Validation loss decreased (634.848145 --> 581.574341).  Saving model ...
# [ 12/300] train_loss: 539.59265 valid_loss: 504.23724
# Validation loss decreased (581.574341 --> 504.237244).  Saving model ...
# [ 13/300] train_loss: 448.22266 valid_loss: 396.74887
# Validation loss decreased (504.237244 --> 396.748871).  Saving model ...
# [ 14/300] train_loss: 318.66010 valid_loss: 286.33026
# Validation loss decreased (396.748871 --> 286.330261).  Saving model ...
# [ 15/300] train_loss: 183.62335 valid_loss: 313.17963
# EarlyStopping counter: 1 out of 30
# [ 16/300] train_loss: 180.99278 valid_loss: 239.80745
# Validation loss decreased (286.330261 --> 239.807449).  Saving model ...
# [ 17/300] train_loss: 176.35368 valid_loss: 290.38336
# EarlyStopping counter: 1 out of 30
# [ 18/300] train_loss: 274.22662 valid_loss: 147.28023
# Validation loss decreased (239.807449 --> 147.280228).  Saving model ...
# [ 19/300] train_loss: 129.47160 valid_loss: 132.19420
# Validation loss decreased (147.280228 --> 132.194199).  Saving model ...
# [ 20/300] train_loss: 120.80536 valid_loss: 114.99995
# Validation loss decreased (132.194199 --> 114.999947).  Saving model ...
# [ 21/300] train_loss: 102.36202 valid_loss: 92.78374
# Validation loss decreased (114.999947 --> 92.783737).  Saving model ...
# [ 22/300] train_loss: 83.88543 valid_loss: 94.05264
# EarlyStopping counter: 1 out of 30
# [ 23/300] train_loss: 84.72891 valid_loss: 97.06754
# EarlyStopping counter: 2 out of 30
# [ 24/300] train_loss: 98.18889 valid_loss: 91.26906
# Validation loss decreased (92.783737 --> 91.269058).  Saving model ...
# [ 25/300] train_loss: 103.30685 valid_loss: 77.19247
# Validation loss decreased (91.269058 --> 77.192467).  Saving model ...
# [ 26/300] train_loss: 89.35303 valid_loss: 59.76220
# Validation loss decreased (77.192467 --> 59.762203).  Saving model ...
# [ 27/300] train_loss: 72.50259 valid_loss: 46.62516
# Validation loss decreased (59.762203 --> 46.625156).  Saving model ...
# [ 28/300] train_loss: 54.34633 valid_loss: 44.74361
# Validation loss decreased (46.625156 --> 44.743614).  Saving model ...
# [ 29/300] train_loss: 48.61520 valid_loss: 50.29105
# EarlyStopping counter: 1 out of 30
# [ 30/300] train_loss: 53.13522 valid_loss: 50.52893
# EarlyStopping counter: 2 out of 30
# [ 31/300] train_loss: 55.74649 valid_loss: 40.45113
# Validation loss decreased (44.743614 --> 40.451130).  Saving model ...
# [ 32/300] train_loss: 48.97304 valid_loss: 30.97435
# Validation loss decreased (40.451130 --> 30.974348).  Saving model ...
# [ 33/300] train_loss: 42.87852 valid_loss: 29.84224
# Validation loss decreased (30.974348 --> 29.842243).  Saving model ...
# [ 34/300] train_loss: 40.12447 valid_loss: 32.36805
# EarlyStopping counter: 1 out of 30
# [ 35/300] train_loss: 37.13182 valid_loss: 33.81023
# EarlyStopping counter: 2 out of 30
# [ 36/300] train_loss: 37.59676 valid_loss: 33.74109
# EarlyStopping counter: 3 out of 30
# [ 37/300] train_loss: 32.50097 valid_loss: 34.57202
# EarlyStopping counter: 4 out of 30
# [ 38/300] train_loss: 32.25365 valid_loss: 36.68596
# EarlyStopping counter: 5 out of 30
# [ 39/300] train_loss: 31.00896 valid_loss: 38.53281
# EarlyStopping counter: 6 out of 30
# [ 40/300] train_loss: 28.91395 valid_loss: 39.21586
# EarlyStopping counter: 7 out of 30
# [ 41/300] train_loss: 31.02141 valid_loss: 39.46069
# EarlyStopping counter: 8 out of 30
# [ 42/300] train_loss: 29.97539 valid_loss: 38.61837
# EarlyStopping counter: 9 out of 30
# [ 43/300] train_loss: 29.41103 valid_loss: 36.08154
# EarlyStopping counter: 10 out of 30
# [ 44/300] train_loss: 28.31178 valid_loss: 32.27401
# EarlyStopping counter: 11 out of 30
# [ 45/300] train_loss: 25.55847 valid_loss: 28.44932
# Validation loss decreased (29.842243 --> 28.449320).  Saving model ...
# [ 46/300] train_loss: 24.37578 valid_loss: 25.44336
# Validation loss decreased (28.449320 --> 25.443361).  Saving model ...
# [ 47/300] train_loss: 21.86810 valid_loss: 23.46309
# Validation loss decreased (25.443361 --> 23.463085).  Saving model ...
# [ 48/300] train_loss: 22.00751 valid_loss: 22.09705
# Validation loss decreased (23.463085 --> 22.097052).  Saving model ...
# [ 49/300] train_loss: 21.44172 valid_loss: 21.07622
# Validation loss decreased (22.097052 --> 21.076220).  Saving model ...
# [ 50/300] train_loss: 23.29774 valid_loss: 20.16650
# Validation loss decreased (21.076220 --> 20.166502).  Saving model ...
# [ 51/300] train_loss: 20.57262 valid_loss: 19.35640
# Validation loss decreased (20.166502 --> 19.356400).  Saving model ...
# [ 52/300] train_loss: 18.80248 valid_loss: 18.92610
# Validation loss decreased (19.356400 --> 18.926098).  Saving model ...
# [ 53/300] train_loss: 15.33793 valid_loss: 19.15009
# EarlyStopping counter: 1 out of 30
# [ 54/300] train_loss: 17.26577 valid_loss: 19.76568
# EarlyStopping counter: 2 out of 30
# [ 55/300] train_loss: 15.66886 valid_loss: 20.24731
# EarlyStopping counter: 3 out of 30
# [ 56/300] train_loss: 17.91143 valid_loss: 20.55258
# EarlyStopping counter: 4 out of 30
# [ 57/300] train_loss: 16.67054 valid_loss: 20.33603
# EarlyStopping counter: 5 out of 30
# [ 58/300] train_loss: 16.07307 valid_loss: 19.68445
# EarlyStopping counter: 6 out of 30
# [ 59/300] train_loss: 14.01859 valid_loss: 18.68263
# Validation loss decreased (18.926098 --> 18.682629).  Saving model ...
# [ 60/300] train_loss: 14.10922 valid_loss: 17.22853
# Validation loss decreased (18.682629 --> 17.228531).  Saving model ...
# [ 61/300] train_loss: 14.06615 valid_loss: 15.84539
# Validation loss decreased (17.228531 --> 15.845391).  Saving model ...
# [ 62/300] train_loss: 14.47405 valid_loss: 15.04414
# Validation loss decreased (15.845391 --> 15.044137).  Saving model ...
# [ 63/300] train_loss: 11.96599 valid_loss: 14.58826
# Validation loss decreased (15.044137 --> 14.588256).  Saving model ...
# [ 64/300] train_loss: 12.97671 valid_loss: 14.28006
# Validation loss decreased (14.588256 --> 14.280060).  Saving model ...
# [ 65/300] train_loss: 12.58500 valid_loss: 14.30682
# EarlyStopping counter: 1 out of 30
# [ 66/300] train_loss: 11.15083 valid_loss: 14.80045
# EarlyStopping counter: 2 out of 30
# [ 67/300] train_loss: 11.78941 valid_loss: 15.47531
# EarlyStopping counter: 3 out of 30
# [ 68/300] train_loss: 11.27836 valid_loss: 16.18468
# EarlyStopping counter: 4 out of 30
# [ 69/300] train_loss: 11.68966 valid_loss: 16.39919
# EarlyStopping counter: 5 out of 30
# [ 70/300] train_loss: 9.70291 valid_loss: 16.56624
# EarlyStopping counter: 6 out of 30
# [ 71/300] train_loss: 11.47540 valid_loss: 16.25181
# EarlyStopping counter: 7 out of 30
# [ 72/300] train_loss: 9.47140 valid_loss: 15.48195
# EarlyStopping counter: 8 out of 30
# [ 73/300] train_loss: 8.82279 valid_loss: 14.73149
# EarlyStopping counter: 9 out of 30
# [ 74/300] train_loss: 8.70831 valid_loss: 14.03826
# Validation loss decreased (14.280060 --> 14.038262).  Saving model ...
# [ 75/300] train_loss: 8.68415 valid_loss: 13.57458
# Validation loss decreased (14.038262 --> 13.574580).  Saving model ...
# [ 76/300] train_loss: 8.73803 valid_loss: 13.12946
# Validation loss decreased (13.574580 --> 13.129461).  Saving model ...
# [ 77/300] train_loss: 8.39099 valid_loss: 13.11961
# Validation loss decreased (13.129461 --> 13.119609).  Saving model ...
# [ 78/300] train_loss: 9.52618 valid_loss: 13.00858
# Validation loss decreased (13.119609 --> 13.008575).  Saving model ...
# [ 79/300] train_loss: 8.48617 valid_loss: 13.07435
# EarlyStopping counter: 1 out of 30
# [ 80/300] train_loss: 7.28834 valid_loss: 13.01054
# EarlyStopping counter: 2 out of 30
# [ 81/300] train_loss: 8.51569 valid_loss: 13.24724
# EarlyStopping counter: 3 out of 30
# [ 82/300] train_loss: 7.25001 valid_loss: 13.87338
# EarlyStopping counter: 4 out of 30
# [ 83/300] train_loss: 8.55190 valid_loss: 14.54495
# EarlyStopping counter: 5 out of 30
# [ 84/300] train_loss: 8.44055 valid_loss: 14.48596
# EarlyStopping counter: 6 out of 30
# [ 85/300] train_loss: 7.54105 valid_loss: 13.99703
# EarlyStopping counter: 7 out of 30
# [ 86/300] train_loss: 7.10300 valid_loss: 12.48622
# Validation loss decreased (13.008575 --> 12.486217).  Saving model ...
# [ 87/300] train_loss: 7.05988 valid_loss: 11.48655
# Validation loss decreased (12.486217 --> 11.486552).  Saving model ...
# [ 88/300] train_loss: 6.72861 valid_loss: 11.19723
# Validation loss decreased (11.486552 --> 11.197232).  Saving model ...
# [ 89/300] train_loss: 6.07695 valid_loss: 11.30275
# EarlyStopping counter: 1 out of 30
# [ 90/300] train_loss: 6.26453 valid_loss: 12.17673
# EarlyStopping counter: 2 out of 30
# [ 91/300] train_loss: 6.27325 valid_loss: 12.64343
# EarlyStopping counter: 3 out of 30
# [ 92/300] train_loss: 5.52366 valid_loss: 11.92561
# EarlyStopping counter: 4 out of 30
# [ 93/300] train_loss: 5.23243 valid_loss: 11.16871
# Validation loss decreased (11.197232 --> 11.168715).  Saving model ...
# [ 94/300] train_loss: 6.45156 valid_loss: 10.79292
# Validation loss decreased (11.168715 --> 10.792923).  Saving model ...
# [ 95/300] train_loss: 6.20993 valid_loss: 10.70237
# Validation loss decreased (10.792923 --> 10.702367).  Saving model ...
# [ 96/300] train_loss: 5.78626 valid_loss: 10.96372
# EarlyStopping counter: 1 out of 30
# [ 97/300] train_loss: 6.12314 valid_loss: 11.45884
# EarlyStopping counter: 2 out of 30
# [ 98/300] train_loss: 5.46896 valid_loss: 11.29701
# EarlyStopping counter: 3 out of 30
# [ 99/300] train_loss: 4.52119 valid_loss: 10.63429
# Validation loss decreased (10.702367 --> 10.634290).  Saving model ...
# [100/300] train_loss: 5.34816 valid_loss: 10.29418
# Validation loss decreased (10.634290 --> 10.294184).  Saving model ...
# [101/300] train_loss: 5.64268 valid_loss: 10.14382
# Validation loss decreased (10.294184 --> 10.143823).  Saving model ...
# [102/300] train_loss: 4.13766 valid_loss: 10.46354
# EarlyStopping counter: 1 out of 30
# [103/300] train_loss: 4.75885 valid_loss: 10.73525
# EarlyStopping counter: 2 out of 30
# [104/300] train_loss: 5.16121 valid_loss: 10.36198
# EarlyStopping counter: 3 out of 30
# [105/300] train_loss: 4.62104 valid_loss: 10.03216
# Validation loss decreased (10.143823 --> 10.032159).  Saving model ...
# [106/300] train_loss: 4.99815 valid_loss: 9.34752
# Validation loss decreased (10.032159 --> 9.347521).  Saving model ...
# [107/300] train_loss: 4.83216 valid_loss: 8.91921
# Validation loss decreased (9.347521 --> 8.919209).  Saving model ...
# [108/300] train_loss: 3.97810 valid_loss: 8.72640
# Validation loss decreased (8.919209 --> 8.726400).  Saving model ...
# [109/300] train_loss: 5.14043 valid_loss: 8.94330
# EarlyStopping counter: 1 out of 30
# [110/300] train_loss: 5.96901 valid_loss: 9.62601
# EarlyStopping counter: 2 out of 30
# [111/300] train_loss: 4.87498 valid_loss: 9.38381
# EarlyStopping counter: 3 out of 30
# [112/300] train_loss: 3.98519 valid_loss: 8.75445
# EarlyStopping counter: 4 out of 30
# [113/300] train_loss: 4.41170 valid_loss: 8.71257
# Validation loss decreased (8.726400 --> 8.712567).  Saving model ...
# [114/300] train_loss: 3.97635 valid_loss: 9.01552
# EarlyStopping counter: 1 out of 30
# [115/300] train_loss: 4.62857 valid_loss: 9.36687
# EarlyStopping counter: 2 out of 30
# [116/300] train_loss: 4.28242 valid_loss: 9.68377
# EarlyStopping counter: 3 out of 30
# [117/300] train_loss: 4.47919 valid_loss: 9.06863
# EarlyStopping counter: 4 out of 30
# [118/300] train_loss: 4.50782 valid_loss: 8.55402
# Validation loss decreased (8.712567 --> 8.554015).  Saving model ...
# [119/300] train_loss: 3.79722 valid_loss: 8.41518
# Validation loss decreased (8.554015 --> 8.415183).  Saving model ...
# [120/300] train_loss: 4.18937 valid_loss: 8.75044
# EarlyStopping counter: 1 out of 30
# [121/300] train_loss: 4.43934 valid_loss: 8.95941
# EarlyStopping counter: 2 out of 30
# [122/300] train_loss: 3.11516 valid_loss: 8.87806
# EarlyStopping counter: 3 out of 30
# [123/300] train_loss: 3.80609 valid_loss: 9.08146
# EarlyStopping counter: 4 out of 30
# [124/300] train_loss: 3.76200 valid_loss: 9.24925
# EarlyStopping counter: 5 out of 30
# [125/300] train_loss: 3.91230 valid_loss: 9.07891
# EarlyStopping counter: 6 out of 30
# [126/300] train_loss: 3.35418 valid_loss: 8.92304
# EarlyStopping counter: 7 out of 30
# [127/300] train_loss: 3.29306 valid_loss: 8.34205
# Validation loss decreased (8.415183 --> 8.342052).  Saving model ...
# [128/300] train_loss: 3.18930 valid_loss: 7.89569
# Validation loss decreased (8.342052 --> 7.895694).  Saving model ...
# [129/300] train_loss: 2.76030 valid_loss: 7.81837
# Validation loss decreased (7.895694 --> 7.818367).  Saving model ...
# [130/300] train_loss: 3.02235 valid_loss: 7.82994
# EarlyStopping counter: 1 out of 30
# [131/300] train_loss: 2.91590 valid_loss: 7.92999
# EarlyStopping counter: 2 out of 30
# [132/300] train_loss: 2.74589 valid_loss: 7.64410
# Validation loss decreased (7.818367 --> 7.644098).  Saving model ...
# [133/300] train_loss: 3.79120 valid_loss: 7.37142
# Validation loss decreased (7.644098 --> 7.371419).  Saving model ...
# [134/300] train_loss: 3.41717 valid_loss: 7.36237
# Validation loss decreased (7.371419 --> 7.362370).  Saving model ...
# [135/300] train_loss: 3.60685 valid_loss: 7.60294
# EarlyStopping counter: 1 out of 30
# [136/300] train_loss: 3.39494 valid_loss: 7.88377
# EarlyStopping counter: 2 out of 30
# [137/300] train_loss: 2.69231 valid_loss: 8.26620
# EarlyStopping counter: 3 out of 30
# [138/300] train_loss: 2.97375 valid_loss: 8.46859
# EarlyStopping counter: 4 out of 30
# [139/300] train_loss: 2.99730 valid_loss: 7.91624
# EarlyStopping counter: 5 out of 30
# [140/300] train_loss: 3.43885 valid_loss: 7.30956
# Validation loss decreased (7.362370 --> 7.309562).  Saving model ...
# [141/300] train_loss: 3.12722 valid_loss: 7.01304
# Validation loss decreased (7.309562 --> 7.013036).  Saving model ...
# [142/300] train_loss: 2.71813 valid_loss: 6.74896
# Validation loss decreased (7.013036 --> 6.748961).  Saving model ...
# [143/300] train_loss: 3.24926 valid_loss: 6.61208
# Validation loss decreased (6.748961 --> 6.612076).  Saving model ...
# [144/300] train_loss: 2.69917 valid_loss: 6.89636
# EarlyStopping counter: 1 out of 30
# [145/300] train_loss: 3.33099 valid_loss: 6.89782
# EarlyStopping counter: 2 out of 30
# [146/300] train_loss: 2.95933 valid_loss: 6.61277
# EarlyStopping counter: 3 out of 30
# [147/300] train_loss: 2.57039 valid_loss: 6.58518
# Validation loss decreased (6.612076 --> 6.585179).  Saving model ...
# [148/300] train_loss: 3.24414 valid_loss: 7.03655
# EarlyStopping counter: 1 out of 30
# [149/300] train_loss: 2.58456 valid_loss: 7.36694
# EarlyStopping counter: 2 out of 30
# [150/300] train_loss: 2.97478 valid_loss: 7.22289
# EarlyStopping counter: 3 out of 30
# [151/300] train_loss: 3.14874 valid_loss: 6.97238
# EarlyStopping counter: 4 out of 30
# [152/300] train_loss: 3.28499 valid_loss: 7.17345
# EarlyStopping counter: 5 out of 30
# [153/300] train_loss: 2.47609 valid_loss: 7.15520
# EarlyStopping counter: 6 out of 30
# [154/300] train_loss: 2.85470 valid_loss: 7.07366
# EarlyStopping counter: 7 out of 30
# [155/300] train_loss: 2.66919 valid_loss: 6.96568
# EarlyStopping counter: 8 out of 30
# [156/300] train_loss: 2.86219 valid_loss: 6.84246
# EarlyStopping counter: 9 out of 30
# [157/300] train_loss: 2.85098 valid_loss: 6.64308
# EarlyStopping counter: 10 out of 30
# [158/300] train_loss: 2.99966 valid_loss: 6.38146
# Validation loss decreased (6.585179 --> 6.381457).  Saving model ...
# [159/300] train_loss: 2.54826 valid_loss: 6.28001
# Validation loss decreased (6.381457 --> 6.280005).  Saving model ...
# [160/300] train_loss: 3.07261 valid_loss: 6.18572
# Validation loss decreased (6.280005 --> 6.185724).  Saving model ...
# [161/300] train_loss: 2.70865 valid_loss: 6.50252
# EarlyStopping counter: 1 out of 30
# [162/300] train_loss: 2.45922 valid_loss: 6.94825
# EarlyStopping counter: 2 out of 30
# [163/300] train_loss: 2.29202 valid_loss: 6.67342
# EarlyStopping counter: 3 out of 30
# [164/300] train_loss: 2.47060 valid_loss: 6.46061
# EarlyStopping counter: 4 out of 30
# [165/300] train_loss: 2.62718 valid_loss: 6.41263
# EarlyStopping counter: 5 out of 30
# [166/300] train_loss: 2.34822 valid_loss: 6.53320
# EarlyStopping counter: 6 out of 30
# [167/300] train_loss: 2.36050 valid_loss: 6.66637
# EarlyStopping counter: 7 out of 30
# [168/300] train_loss: 3.44582 valid_loss: 6.13952
# Validation loss decreased (6.185724 --> 6.139515).  Saving model ...
# [169/300] train_loss: 2.46245 valid_loss: 5.81054
# Validation loss decreased (6.139515 --> 5.810541).  Saving model ...
# [170/300] train_loss: 2.66801 valid_loss: 5.80800
# Validation loss decreased (5.810541 --> 5.808000).  Saving model ...
# [171/300] train_loss: 2.73745 valid_loss: 5.82007
# EarlyStopping counter: 1 out of 30
# [172/300] train_loss: 2.66480 valid_loss: 6.01230
# EarlyStopping counter: 2 out of 30
# [173/300] train_loss: 2.17542 valid_loss: 6.38252
# EarlyStopping counter: 3 out of 30
# [174/300] train_loss: 2.87845 valid_loss: 6.45417
# EarlyStopping counter: 4 out of 30
# [175/300] train_loss: 1.77075 valid_loss: 6.64017
# EarlyStopping counter: 5 out of 30
# [176/300] train_loss: 2.25401 valid_loss: 6.67463
# EarlyStopping counter: 6 out of 30
# [177/300] train_loss: 2.57404 valid_loss: 6.32418
# EarlyStopping counter: 7 out of 30
# [178/300] train_loss: 2.09346 valid_loss: 6.06039
# EarlyStopping counter: 8 out of 30
# [179/300] train_loss: 2.98814 valid_loss: 5.90350
# EarlyStopping counter: 9 out of 30
# [180/300] train_loss: 2.83787 valid_loss: 5.97758
# EarlyStopping counter: 10 out of 30
# [181/300] train_loss: 2.04541 valid_loss: 6.31514
# EarlyStopping counter: 11 out of 30
# [182/300] train_loss: 2.60810 valid_loss: 6.10957
# EarlyStopping counter: 12 out of 30
# [183/300] train_loss: 2.51028 valid_loss: 6.02269
# EarlyStopping counter: 13 out of 30
# [184/300] train_loss: 2.06905 valid_loss: 6.11169
# EarlyStopping counter: 14 out of 30
# [185/300] train_loss: 2.27602 valid_loss: 6.36436
# EarlyStopping counter: 15 out of 30
# [186/300] train_loss: 2.26121 valid_loss: 6.72201
# EarlyStopping counter: 16 out of 30
# [187/300] train_loss: 2.33275 valid_loss: 6.58169
# EarlyStopping counter: 17 out of 30
# [188/300] train_loss: 2.47323 valid_loss: 6.37469
# EarlyStopping counter: 18 out of 30
# [189/300] train_loss: 2.07249 valid_loss: 6.31168
# EarlyStopping counter: 19 out of 30
# [190/300] train_loss: 2.83596 valid_loss: 6.19723
# EarlyStopping counter: 20 out of 30
# [191/300] train_loss: 1.70398 valid_loss: 6.13554
# EarlyStopping counter: 21 out of 30
# [192/300] train_loss: 2.37458 valid_loss: 6.18264
# EarlyStopping counter: 22 out of 30
# [193/300] train_loss: 2.40356 valid_loss: 5.84568
# EarlyStopping counter: 23 out of 30
# [194/300] train_loss: 1.80629 valid_loss: 5.48579
# Validation loss decreased (5.808000 --> 5.485792).  Saving model ...
# [195/300] train_loss: 2.27326 valid_loss: 5.30435
# Validation loss decreased (5.485792 --> 5.304348).  Saving model ...
# [196/300] train_loss: 2.79300 valid_loss: 5.35492
# EarlyStopping counter: 1 out of 30
# [197/300] train_loss: 2.66999 valid_loss: 6.10383
# EarlyStopping counter: 2 out of 30
# [198/300] train_loss: 2.44986 valid_loss: 7.23847
# EarlyStopping counter: 3 out of 30
# [199/300] train_loss: 2.28359 valid_loss: 6.75045
# EarlyStopping counter: 4 out of 30
# [200/300] train_loss: 2.28163 valid_loss: 6.10372
# EarlyStopping counter: 5 out of 30
# [201/300] train_loss: 1.86146 valid_loss: 5.98784
# EarlyStopping counter: 6 out of 30
# [202/300] train_loss: 2.52111 valid_loss: 5.83509
# EarlyStopping counter: 7 out of 30
# [203/300] train_loss: 2.59983 valid_loss: 6.38221
# EarlyStopping counter: 8 out of 30
# [204/300] train_loss: 2.38668 valid_loss: 6.14288
# EarlyStopping counter: 9 out of 30
# [205/300] train_loss: 2.19621 valid_loss: 6.22120
# EarlyStopping counter: 10 out of 30
# [206/300] train_loss: 2.25575 valid_loss: 6.35345
# EarlyStopping counter: 11 out of 30
# [207/300] train_loss: 2.23744 valid_loss: 6.32469
# EarlyStopping counter: 12 out of 30
# [208/300] train_loss: 2.26693 valid_loss: 6.30379
# EarlyStopping counter: 13 out of 30
# [209/300] train_loss: 2.07899 valid_loss: 6.33051
# EarlyStopping counter: 14 out of 30
# [210/300] train_loss: 2.31681 valid_loss: 6.34630
# EarlyStopping counter: 15 out of 30
# [211/300] train_loss: 2.54644 valid_loss: 6.41001
# EarlyStopping counter: 16 out of 30
# [212/300] train_loss: 2.18726 valid_loss: 6.38416
# EarlyStopping counter: 17 out of 30
# [213/300] train_loss: 2.18680 valid_loss: 6.41674
# EarlyStopping counter: 18 out of 30
# [214/300] train_loss: 2.14213 valid_loss: 6.54505
# EarlyStopping counter: 19 out of 30
# [215/300] train_loss: 2.66099 valid_loss: 5.85163
# EarlyStopping counter: 20 out of 30
# [216/300] train_loss: 2.16413 valid_loss: 5.05846
# Validation loss decreased (5.304348 --> 5.058465).  Saving model ...
# [217/300] train_loss: 2.28959 valid_loss: 4.98456
# Validation loss decreased (5.058465 --> 4.984561).  Saving model ...
# [218/300] train_loss: 2.23924 valid_loss: 5.32536
# EarlyStopping counter: 1 out of 30
# [219/300] train_loss: 1.64600 valid_loss: 5.80158
# EarlyStopping counter: 2 out of 30
# [220/300] train_loss: 2.52431 valid_loss: 6.04471
# EarlyStopping counter: 3 out of 30
# [221/300] train_loss: 2.44812 valid_loss: 6.35575
# EarlyStopping counter: 4 out of 30
# [222/300] train_loss: 2.06690 valid_loss: 6.45414
# EarlyStopping counter: 5 out of 30
# [223/300] train_loss: 2.09066 valid_loss: 6.61504
# EarlyStopping counter: 6 out of 30
# [224/300] train_loss: 1.88820 valid_loss: 6.82262
# EarlyStopping counter: 7 out of 30
# [225/300] train_loss: 2.20272 valid_loss: 6.07130
# EarlyStopping counter: 8 out of 30
# [226/300] train_loss: 1.82883 valid_loss: 5.74376
# EarlyStopping counter: 9 out of 30
# [227/300] train_loss: 2.20541 valid_loss: 5.60538
# EarlyStopping counter: 10 out of 30
# [228/300] train_loss: 2.27536 valid_loss: 5.60819
# EarlyStopping counter: 11 out of 30
# [229/300] train_loss: 1.95058 valid_loss: 6.25245
# EarlyStopping counter: 12 out of 30
# [230/300] train_loss: 1.98441 valid_loss: 6.05818
# EarlyStopping counter: 13 out of 30
# [231/300] train_loss: 2.24736 valid_loss: 5.88244
# EarlyStopping counter: 14 out of 30
# [232/300] train_loss: 1.80912 valid_loss: 5.82298
# EarlyStopping counter: 15 out of 30
# [233/300] train_loss: 1.80684 valid_loss: 6.07531
# EarlyStopping counter: 16 out of 30
# [234/300] train_loss: 1.31272 valid_loss: 6.23659
# EarlyStopping counter: 17 out of 30
# [235/300] train_loss: 2.59478 valid_loss: 6.37391
# EarlyStopping counter: 18 out of 30
# [236/300] train_loss: 2.21139 valid_loss: 5.96382
# EarlyStopping counter: 19 out of 30
# [237/300] train_loss: 1.94985 valid_loss: 5.80337
# EarlyStopping counter: 20 out of 30
# [238/300] train_loss: 2.36320 valid_loss: 5.92246
# EarlyStopping counter: 21 out of 30
# [239/300] train_loss: 1.84600 valid_loss: 6.27006
# EarlyStopping counter: 22 out of 30
# [240/300] train_loss: 1.73081 valid_loss: 6.51308
# EarlyStopping counter: 23 out of 30
# [241/300] train_loss: 1.82290 valid_loss: 6.62893
# EarlyStopping counter: 24 out of 30
# [242/300] train_loss: 2.02496 valid_loss: 6.33360
# EarlyStopping counter: 25 out of 30
# [243/300] train_loss: 1.85309 valid_loss: 5.90998
# EarlyStopping counter: 26 out of 30
# [244/300] train_loss: 1.37095 valid_loss: 5.56529
# EarlyStopping counter: 27 out of 30
# [245/300] train_loss: 2.14850 valid_loss: 5.49942
# EarlyStopping counter: 28 out of 30
# [246/300] train_loss: 1.77308 valid_loss: 5.76729
# EarlyStopping counter: 29 out of 30
# [247/300] train_loss: 1.55448 valid_loss: 6.04738
# EarlyStopping counter: 30 out of 30
# Early stopping

# %% [markdown]
# <STEP 5> 학습 결과 표시, 테스트 파일 각도 예측

# %%
def resultShow():
  test_dataset = CustomDataset(x_exam_Image, y_exam_Angle)
  test_loader = DataLoader(test_dataset, batch_size=len(x_exam_Image))

  model = NvidiaModel().to(device)
  model.load_state_dict(torch.load(f'{outDir}/{project}_model_check.pt'))
  # model = torch.load(f'{outDir}/{project}_model_check.pt')
  model.eval()
  
  y_pred = []
  y_target = []

  with torch.no_grad():
        for data, target in test_loader:
            data, target = data.to(device), target.to(device)

            output = model(data)

            print('pred', output.to('cpu').numpy())
            print('target', target.to('cpu').numpy())

            for output_data, target_data in zip(output.to('cpu').numpy(), target.to('cpu').numpy()):
              y_pred.append(output_data)
              y_target.append(target_data)
  
  mse = mean_squared_error(y_target, y_pred)
  r2s = r2_score(y_target, y_pred)
  #-----------------------------------------------------------------------------
  print('\n표준 편차:', f'{mse:.2}')
  print('회귀 결정 계수:', f'{r2s:.2%}')
  #-----------------------------------------------------------------------------
  fig, axes = plt.subplots(1, len(x_exam_Image), figsize=(30, 2+3))
  xTImg = imgPaths(x_exam_Image)                                                # 파일 이름 앞에 경로(path) 추가
  for x, c in enumerate(xTImg):
      axes[x].imshow(Image.open(c))    
      t = x_exam_Image[x] +' / E:'+str(int(y_pred[x]))
      axes[x].set_title(t)
      axes[x].xaxis.set_ticks([])
      axes[x].yaxis.set_ticks([])

if len(x_exam_Image): resultShow()
print("학습 소요 시간:", int(elapsedTime/60), '분', elapsedTime%60, '초' )      # 학습 소요시간 프린트
# Out:
# pred [[-41.843933  ]
#  [-18.25978   ]
#  [ -0.15916517]
#  [ 11.2183695 ]
#  [ 43.58277   ]]
# target [[-42.]
#  [-18.]
#  [  0.]
#  [ 12.]
#  [ 42.]]
#
# 표준 편차: 0.65
# 회귀 결정 계수: 99.92%
# 학습 소요 시간: 3 분 35 초
